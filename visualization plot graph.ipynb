# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\galiv\appdata\local\programs\python\python313\lib\site-packages (6.1.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\galiv\appdata\local\programs\python\python313\lib\site-packages (from plotly) (1.42.1)
# Requirement already satisfied: packaging in c:\users\galiv\appdata\roaming\python\python313\site-packages (from plotly) (25.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\galiv\appdata\local\programs\python\python313\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\galiv\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.3.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\galiv\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.3.0)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\galiv\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\galiv\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\galiv\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\galiv\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\galiv\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\galiv\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\galiv\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\galiv\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\galiv\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.shape
# Out:
# (891, 15)

# %%
sns.countplot(x="alive",data=df)
# Out:
# <Axes: xlabel='alive', ylabel='count'>

# %%
sns.countplot(x="alone",data=df)
# Out:
# <Axes: xlabel='alone', ylabel='count'>

# %%
sns.barplot(x="sex",y="class",data=df)
# Out:
# <Axes: xlabel='sex', ylabel='class'>

# %%
sns.boxplot(df['age'])
# Out:
# <Axes: ylabel='age'>

# %%
sns.boxplot(x='class',y='age',data=df)
# Out:
# <Axes: xlabel='class', ylabel='age'>

# %%
sns.violinplot(x='survived',y='fare',data=df)
# Out:
# <Axes: xlabel='survived', ylabel='fare'>

# %%
sns.heatmap(df.select_dtypes(include='number').corr(),annot=True,cmap='magma')
# Out:
# <Axes: >

# %%
sns.swarmplot(x='sex',y='age',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='age'>

# %%
sns.histplot(df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
sns.jointplot(data=df,x="age",y="fare")

# %%
g=sns.JointGrid(data=df,x='age',y='fare')
g.plot_joint(sns.scatterplot)
g.plot_marginals(sns.kdeplot)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.pairplot(df[['age','fare']])

# %%
df_numeric=df[["age","fare","pclass"]].dropna()
df_numeric.head()
# Out:
#     age     fare  pclass
# 0  22.0   7.2500       3
# 1  38.0  71.2833       1
# 2  26.0   7.9250       3
# 3  35.0  53.1000       1
# 4  35.0   8.0500       3

# %%
g =sns.PairGrid(df_numeric)
g.map_diag(sns.histplot,fill=True)
g.map_offdiag(sns.scatterplot)
plt.show()

# %%
g=sns.PairGrid(df_numeric)
g.map_upper(sns.kdeplot,fill=True)
g.map_lower(sns.regplot)
g.map_diag(sns.histplot,fill=True)
plt.show()

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df['sex'].nunique()
# Out:
# 2

# %%
df['pclass'].nunique()
# Out:
# 3

# %%
df['pclass'].nunique()
# Out:
# 3

# %%
g=sns.FacetGrid(df,row='sex',col='survived')
g.map(sns.histplot,'age')

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
sns.barplot(x="class",y='fare',data=df,estimator=np.std)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
pip install ipykernel
# Out:
# Requirement already satisfied: ipykernel in c:\users\galiv\appdata\roaming\python\python313\site-packages (6.29.5)
# Requirement already satisfied: comm>=0.1.1 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipykernel) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipykernel) (1.8.14)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipykernel) (9.3.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipykernel) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipykernel) (25.0)
# Requirement already satisfied: psutil in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipykernel) (7.0.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipykernel) (27.0.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipykernel) (6.5.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: colorama in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\galiv\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from jupyter-client>=6.1.12->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.3.8)
# Requirement already satisfied: pywin32>=300 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (310)
# Requirement already satisfied: six>=1.5 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\galiv\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\galiv\appdata\local\programs\python\python313\lib\site-packages (6.1.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\galiv\appdata\local\programs\python\python313\lib\site-packages (from plotly) (1.42.1)
# Requirement already satisfied: packaging in c:\users\galiv\appdata\roaming\python\python313\site-packages (from plotly) (25.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
px.pie(df,names="survived",title="survival Distribution")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 px.pie(df,names="survived",title="survival Distribution")
#
# NameError: name 'df' is not defined

# %%
pip install ipython
# Out:
# Requirement already satisfied: ipython in c:\users\galiv\appdata\roaming\python\python313\site-packages (9.3.0)
# Requirement already satisfied: colorama in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: decorator in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipython) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipython) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipython) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipython) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipython) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from ipython) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\galiv\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from jedi>=0.16->ipython) (0.8.4)
# Requirement already satisfied: executing>=1.2.0 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from stack_data->ipython) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from stack_data->ipython) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\galiv\appdata\roaming\python\python313\site-packages (from stack_data->ipython) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
px.violin(df,x="survived",y="age",box=True,points="all",title="Age Distribution by survival").show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 px.violin(df,x="survived",y="age",box=True,points="all",title="Age Distribution by survival").show()
#
# File c:\Users\galiv\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\basedatatypes.py:3436, in BaseFigure.show(self, *args, **kwargs)
#    3403 """
#    3404 Show a figure using either the default renderer(s) or the renderer(s)
#    3405 specified by the renderer argument
#    (...)   3432 None
#    3433 """
#    3434 import plotly.io as pio
# -> 3436 return pio.show(self, *args, **kwargs)
#
# File c:\Users\galiv\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\io\_renderers.py:425, in show(fig, renderer, validate, **kwargs)
#     420     raise ValueError(
#     421         "Mime type rendering requires ipython but it is not installed"
#     422     )
#     424 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 425     raise ValueError(
#     426         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     427     )
#     429 display_jupyter_version_warnings()
#     431 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %%
pip install plotly.express
# Out:
# Collecting plotly.express
#   Downloading plotly_express-0.4.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\galiv\appdata\local\programs\python\python313\lib\site-packages (from plotly.express) (2.3.0)
# Requirement already satisfied: plotly>=4.1.0 in c:\users\galiv\appdata\local\programs\python\python313\lib\site-packages (from plotly.express) (6.1.2)
# Collecting statsmodels>=0.9.0 (from plotly.express)
#   Downloading statsmodels-0.14.4-cp313-cp313-win_amd64.whl.metadata (9.5 kB)
# Collecting scipy>=0.18 (from plotly.express)
#   Downloading scipy-1.16.0-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting patsy>=0.5 (from plotly.express)
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: numpy>=1.11 in c:\users\galiv\appdata\local\programs\python\python313\lib\site-packages (from plotly.express) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from pandas>=0.20.0->plotly.express) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\galiv\appdata\local\programs\python\python313\lib\site-packages (from pandas>=0.20.0->plotly.express) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\galiv\appdata\local\programs\python\python313\lib\site-packages (from pandas>=0.20.0->plotly.express) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\galiv\appdata\local\programs\python\python313\lib\site-packages (from plotly>=4.1.0->plotly.express) (1.42.1)
# Requirement already satisfied: packaging in c:\users\galiv\appdata\roaming\python\python313\site-packages (from plotly>=4.1.0->plotly.express) (25.0)
# Requirement already satisfied: six>=1.5 in c:\users\galiv\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas>=0.20.0->plotly.express) (1.17.0)
# Downloading plotly_express-0.4.1-py2.py3-none-any.whl (2.9 kB)
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Downloading scipy-1.16.0-cp313-cp313-win_amd64.whl (38.4 MB)
#    ---------------------------------------- 0.0/38.4 MB ? eta -:--:--
#    ----- ---------------------------------- 5.5/38.4 MB 25.3 MB/s eta 0:00:02
#    ----------- ---------------------------- 10.7/38.4 MB 25.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 16.3/38.4 MB 25.1 MB/s eta 0:00:01
#    --------------------- ------------------ 20.7/38.4 MB 24.3 MB/s eta 0:00:01
#    --------------------------- ------------ 26.5/38.4 MB 24.6 MB/s eta 0:00:01
#    --------------------------------- ------ 32.0/38.4 MB 24.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.4 MB 25.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.4 MB 25.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.4 MB 25.8 MB/s eta 0:00:01
#    ---------------------------------------  38.3/38.4 MB 25.8 MB/s eta 0:00:01
#    ---------------------------------------- 38.4/38.4 MB 16.8 MB/s eta 0:00:00
# Downloading statsmodels-0.14.4-cp313-cp313-win_amd64.whl (9.8 MB)
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    ---------------------- ----------------- 5.5/9.8 MB 27.2 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.8 MB 28.5 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.8 MB 28.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 14.0 MB/s eta 0:00:00
# Installing collected packages: scipy, patsy, statsmodels, plotly.express
#
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------------------------------------- 0/4 [scipy]
#    ---------- ----------------------------- 1/4 [patsy]
#    ---------- ----------------------------- 1/4 [patsy]
#    ---------- ----------------------------- 1/4 [patsy]
#    ---------- ----------------------------- 1/4 [patsy]
#    ---------- ----------------------------- 1/4 [patsy]
#    ---------- ----------------------------- 1/4 [patsy]
#    ---------- ----------------------------- 1/4 [patsy]
#    ---------- ----------------------------- 1/4 [patsy]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    -------------------- ------------------- 2/4 [statsmodels]
#    ------------------------------ --------- 3/4 [plotly.express]
#    ---------------------------------------- 4/4 [plotly.express]
#
# Successfully installed patsy-1.0.1 plotly.express-0.4.1 scipy-1.16.0 statsmodels-0.14.4
# Note: you may need to restart the kernel to use updated packages.

# %%
for i in range(2,8):
  for j in range(2,i-1):

    print(j , end="  ")
  print("\n")
# Out:
# 2
#
# 2  3
#
# 2  3  4
#
# 2  3  4  5

# %%
x=1
for i in range(5,0,-1):
    print(""*i,x*"*")
    x=x+1
# Out:
#       *
#      **
#     ***
#    ****
#   *****
